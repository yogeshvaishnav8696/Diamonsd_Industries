# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df= pd.read_csv(r'C:\Users\91954\OneDrive\Desktop\diamonds.csv')
print(df)
df.head(5)
df.tail(5)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df.head(5)
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %%
df.isnull().count()
# Out:
# Unnamed: 0    53940
# carat         53940
# cut           53940
# color         53940
# clarity       53940
# depth         53940
# table         53940
# price         53940
# x             53940
# y             53940
# z             53940
# dtype: int64

# %%
df1=df.drop(columns ='Unnamed: 0')
df1
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df1.shape
# Out:
# (53940, 10)

# %%
df1.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df1.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df1['carat'].value_counts()
# Out:
# carat
# 0.30    2604
# 0.31    2249
# 1.01    2242
# 0.70    1981
# 0.32    1840
#         ...
# 3.02       1
# 3.65       1
# 3.50       1
# 3.22       1
# 3.11       1
# Name: count, Length: 273, dtype: int64

# %%
cutcounts=df1['cut'].value_counts()
cutcounts
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
colorcounts=df1['color'].value_counts()
colorcounts
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
calaritycounts=df1['clarity'].value_counts()
calaritycounts
# Out:
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64

# %%
tablecounts=df1['table'].value_counts()
tablecounts
# Out:
# table
# 56.0    9881
# 57.0    9724
# 58.0    8369
# 59.0    6572
# 55.0    6268
#         ...
# 51.6       1
# 63.5       1
# 43.0       1
# 62.4       1
# 61.6       1
# Name: count, Length: 127, dtype: int64

# %%
pricecounts=df1['price'].value_counts()
pricecounts
# Out:
# price
# 605      132
# 802      127
# 625      126
# 828      125
# 776      124
#         ...
# 8816       1
# 14704      1
# 14699      1
# 14698      1
# 9793       1
# Name: count, Length: 11602, dtype: int64

# %%
plt.figure(figsize=[12,6])
plt.hist(df['price'],bins=80,color="hotpink")
plt.xlabel('price in Usd')
plt.ylabel('Frequency')
plt.title('Diamonds price Histogram')
plt.show()

# %%
plt.figure(figsize=[12,6])
plt.hist(df1['price'],bins=80,color="red")
plt.xlabel('price in Usd')
plt.ylabel('Frequency')
plt.title('Diamonds price Histogram')
plt.show()

# %%
plt.figure(figsize=[12,6])
plt.hist(df1['price'],bins=120,color="purple")
plt.xlabel('price in Usd')
plt.ylabel('Frequency')
plt.title('Diamonds price Histogram')
plt.show()

# %%
plt.figure(figsize=[12,6])
plt.hist(df['price'],color="hotpink")
plt.xlabel('price in Usd')
plt.ylabel('Frequency')
plt.title('Diamonds price Histogram')
plt.show()

# %%
plt.figure(figsize=[12,6])
plt.plot(df1['price'],df1['carat'])
plt.title('carat v/s price')
plt.xlabel('price')
plt.ylabel('carat')
plt.show()

# %%
plt.figure(figsize=[12,6])
plt.plot(df1['price'],df1['depth'])
plt.title('depth v/s price')
plt.xlabel('price')
plt.ylabel('depth')
plt.show()

# %%
plt.figure(figsize=[12,6])
cutcounts.plot(kind='line',color="ORANGE")
plt.title('distribution of diamond cut')
plt.xlabel('cut type')
plt.ylabel('frequency')
plt.xticks(rotation=10)
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=[12,6])
cutcounts.plot(kind='line',color="ORANGE")
plt.title('distribution of diamond cut')
plt.xlabel('cut type')
plt.ylabel('frequency')
plt.yticks(rotation=90)
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=[12,6])
cutcounts.plot(kind='bar',color="hotpink")
plt.title('distribution of diamond cut')
plt.xlabel('cut type')
plt.ylabel('frequency')
plt.xticks(rotation=10)
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=[12,6])
colorcounts.plot(kind='bar',color="green")
plt.title('distribution of diamond cut')
plt.xlabel('cut type')
plt.ylabel('frequency')
plt.xticks(rotation=10)
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=[12,6])
colorcounts.plot(kind='line',color="green")
plt.title('distribution of diamond cut')
plt.xlabel('cut type')
plt.ylabel('frequency')
plt.xticks(rotation=10)
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=[12,6])
cutcounts.plot(kind='pie',color="ORANGE")
plt.title('distribution of diamond cut')
plt.xlabel('cut type')
plt.ylabel('frequency')
plt.xticks(rotation=10)
plt.grid(axis="y")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.figure(figsize=[12,6])
#       2 cutcounts.plot(kind='pie',color="ORANGE")
#       3 plt.title('distribution of diamond cut')
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=[12,6])
calaritycounts.plot(kind='line',color="ORANGE")
plt.title('distribution of diamond clarity')
plt.xlabel('clarity type')
plt.ylabel('frequency')
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=[12,6])
calaritycounts.plot(kind='bar',color="ORANGE")
plt.title('distribution of diamond clarity')
plt.xlabel('clarity type')
plt.ylabel('frequency')
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=[12,6])
cutcounts.plot(kind='bar',color="skyblue")
plt.title('distribution of diamond cut')
plt.xlabel('cut type')
plt.ylabel('frequency')
plt.xticks(rotation=0)
plt.grid(axis="y", linestyle='--')
plt.show()

# %%
plt.figure(figsize=[12,6])
cutcounts.plot(kind='pie',autopct=''%1.1f%%',colors=['skyblue','lightgreen''lightcoral','gold'])
plt.title('distribution of diamond cut')
plt.ylabel('')
plt.show()
# Out:
#   Cell In[177], line 2
#     cutcounts.plot(kind='pie',autopct=''%1.1f%%',colors=['skyblue','lightgreen','lightcoral','gold'])
#                                            ^
# SyntaxError: invalid decimal literal

# %%
plt.scatter(df1['x'],df1['y'])
plt.title('x-axis v/s y-axis')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
df1.loc[(df1['x']==0)|(df1['y']==0)|(df1['z']==0)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# 26123   2.25    Premium     I     SI1   61.3   58.0  15397  8.52  8.42  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.00  0.00  0.0
# 27112   2.20    Premium     H     SI1   61.2   59.0  17265  8.42  8.37  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.00  0.00  0.0
# 27503   2.02    Premium     H     VS2   62.7   53.0  18207  8.02  7.95  0.0
# 27739   2.80       Good     G     SI2   63.8   58.0  18788  8.90  8.85  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 51506   1.12    Premium     G      I1   60.4   59.0   2383  6.71  6.67  0.0

# %%
drop_index=df1.loc[(df1['x']==0)|(df1['y']==0)|(df1['z']==0)].index
df1=df1.drop(drop_index)
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean   26972.355731      0.797698     61.749514     57.456834   3930.993231
# std    15571.269010      0.473795      1.432331      2.234064   3987.280446
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13487.750000      0.400000     61.000000     56.000000    949.000000
# 50%    26973.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40457.250000      1.040000     62.500000     59.000000   5323.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53920.000000  53920.000000  53920.000000
# mean       5.731627      5.734887      3.540046
# std        1.119423      1.140126      0.702530
# min        3.730000      3.680000      1.070000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %%
df['color']=df['color'].factorize()[0]
df['cut']=df['cut'].factorize()[0]
df['clarity']=df['clarity'].factorize()[0]
df.head()
# Out:
#    Unnamed: 0  carat  cut  color  clarity  depth  table  price     x     y  \
# 0           1   0.23    0      0        0   61.5   55.0    326  3.95  3.98
# 1           2   0.21    1      0        1   59.8   61.0    326  3.89  3.84
# 2           3   0.23    2      0        2   56.9   65.0    327  4.05  4.07
# 3           4   0.29    1      1        3   62.4   58.0    334  4.20  4.23
# 4           5   0.31    2      2        0   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
buy=df.copy()
buy['price_per_carat']=buy['price']/buy['carat']
buy=buy.sort_values(by='price_per_carat',ascending=True)
print(f"best value for money:{round(min(buy['price_per_carat']),2)}$")
print('the first 3:\n')
buy.head(3)
# Out:
# best value for money:1051.16$
# the first 3:
#        Unnamed: 0  carat  cut  color  clarity  depth  table  price     x  \
# 31962       31963   0.43    1      3        6   62.0   59.0    452  4.78
# 15             16   0.32    1      0        6   60.9   58.0    345  4.38
# 4               5   0.31    2      2        0   63.3   58.0    335  4.34
#
#           y     z  price_per_carat
# 31962  4.83  2.98      1051.162791
# 15     4.42  2.68      1078.125000
# 4      4.35  2.75      1080.645161

# %%
import seaborn as sns
df['cut'].value_counts()
df['color'].value_counts()
df['clarity'].value_counts()
sns.countplot(x='cut',data=df,color='green')
sns.countplot(x='color',data=df,color='green')
sns.countplot(x='clarity',data=df,color='green')
labels=df['cut'].unique()
plt.pie(df['cut'].value_counts(),labels=labels)
plt.show()
labels=df['color'].unique()
plt.pie(df['color'].value_count(),labels=lables)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4080\2457775210.py in ?()
#       8 labels=df['cut'].unique()
#       9 plt.pie(df['cut'].value_counts(),labels=labels)
#      10 plt.show()
#      11 labels=df['color'].unique()
# ---> 12 plt.pie(df['color'].value_count(),labels=lables)
#      13 plt.show()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'
